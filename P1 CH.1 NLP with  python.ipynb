# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Lamia'

# %% [markdown]
# # CH.1 language processing in python

# %% [markdown]
# “from NLTK’s book module, load all items.” The book module contains all the data
# you will need as you read this chapter. After printing a welcome message, it loads the
# text of several books (this will take a few seconds).

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# let’s try generating some random text

# %%
text9.generate()
# Out:
# Building ngram index...
# is , and finding a Sunday teashop , turned in his loose straw hat on
# the bench under the advice of his hands . , or an apple tree , but not
# an anarchist . already irritated nerves ; and Buddhism is not a man
# worth listening to , even if one only laughed at by something at least
# he was -- blood running down his knife and fork . " " I ' d better ."
# the foundation of solid meekness which lies at the anarchist breakfast
# and had been too true . Sunday always insists on the foremost
# ...

# %% [markdown]
# ## What is a token?
# token is the technical name for a sequence of characters—such as hairy, his, or :)—that we want
# to treat as a group

# %%
len(text9)# number of tokens
# Out:
# 69213

# %% [markdown]
# So Genesis has 69,213 words and punctuation symbols, or “tokens.”

# %%
Tokens=set(text9) #list of all words, punctuations and symbols
Tokens#list of all words, punctuations and symbols
# Out:
# {'once',
#  'torments',
#  'abandoned',
#  'funk',
#  'If',
#  'ask',
#  'thrill',
#  'May',
#  'plunge',
#  'mad',
#  'against',
#  'infinity',
#  'emptied',
#  'voiceless',
#  'architecture',
#  'music',
#  'than',
#  'formulate',
#  'Insulted',
#  'pure',
#  'Consequently',
#  'shops',
#  'Tupper',
#  'Dynamiters',
#  'obstacle',
#  'marked',
#  'pair',
#  'clay',
#  'wandering',
#  'sheath',
#  'flask',
#  'opinions',
#  'parcel',
#  'forms',
#  'astonishing',
#  'when',
#  'position',
#  'appear',
#  'beetle',
#  'don',
#  'postman',
#  'feared',
#  'performed',
#  'dresses',
#  'portion',
#  'TWO',
#  'tyrants',
#  'luck',
#  'killing',
#  'tonight',
#  'hurt',
#  'energetic',
#  'prevailed',
#  'Supreme',
#  'miserable',
#  'pursue',
#  'Could',
#  'gravity',
#  'ourang',
#  'change',
#  'spike',
#  'Breakfast',
#  'district',
#  'vanished',
#  'hence',
#  ".'",
#  'lighted',
#  'troubadour',
#  'launch',
#  'later',
#  'affably',
#  'Satanic',
#  'vizards',
#  'triangular',
# ...

# %%
Sorted_tokens=sorted(Tokens)
Sorted_tokens
# Out:
# ['!',
#  '!"',
#  "!'",
#  '!--',
#  '"',
#  '"\'',
#  '"--',
#  '";',
#  "'",
#  "'--",
#  "'.",
#  '\'."',
#  "';",
#  "'?",
#  '\'?"',
#  '(',
#  ')',
#  '),',
#  ').',
#  ')."',
#  '*',
#  ',',
#  ',"',
#  ",'",
#  ',\'"',
#  '-',
#  '--',
#  '--"',
#  "--'",
#  '.',
#  '."',
#  '."\'',
#  ".'",
#  '.\'"',
#  '.--',
#  '1350',
#  '1908',
#  '217',
#  '45',
#  '7',
#  ':',
#  ':--',
#  ';',
#  '?',
#  '?"',
#  "?'",
#  '?)',
#  'A',
#  'ACCUSER',
#  'ACROSS',
#  'ANARCHY',
#  'AS',
#  'AT',
#  'About',
#  'Above',
#  'Absurd',
#  'Accepting',
#  'Acheron',
#  'Across',
#  'Acting',
#  'Adam',
#  'Admiral',
#  'Aesop',
#  'African',
#  'After',
#  'Afterwards',
#  'Again',
#  'Against',
#  'Ages',
#  'Ah',
#  'Albany',
#  'Albert',
#  'Alhambra',
#  'Alice',
#  'All',
#  'Ally',
#  'Almighty',
#  'Almost',
#  'Along',
#  'Alpine',
#  'Also',
#  'Am',
#  'America',
#  'American',
#  'An',
#  'Anarch',
#  'Anarchist',
#  'Anarchists',
#  'Anarchy',
#  'And',
#  'Anne',
#  'Another',
# ...

# %%
len(Tokens) #size of unique types (words,symbols and puncs.)
# Out:
# 6807

# %% [markdown]
# Calculating lexical richness factor معامل الثراء المعجمي :
# Average # of used words

# %%
len(text9) / len(Tokens)
# Out:
# 10.167915381225209

# %%
text9.count("the") #howmany times the word the appeared
# Out:
# 3291

# %%
(text9.count("the")/len(text9))*100 #But be careful, here you considered symbols and punctuations as words
# Out:
# 4.754887087685839

# %%
last_four_tokens=Sorted_tokens[-4:]
last_four_tokens
# Out:
# ['zay', 'ze', 'zem', 'zmite']

# %%
join_last_four_tokens=' '.join(last_four_tokens)
join_last_four_tokens
# Out:
# 'zay ze zem zmite'

# %%
split_last_four_tokens=join_last_four_tokens.split()
split_last_four_tokens
# Out:
# ['zay', 'ze', 'zem', 'zmite']

# %% [markdown]
# # Frequency destribution

# %%
fdist9 = nltk.FreqDist(text9)
fdist9 #dictionary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e9dc1759c099> in <module>
# ----> 1 fdist9 = nltk.FreqDist(text9)
#       2 fdist9 #dictionary
#
# NameError: name 'nltk' is not defined

# %%
fdist9['the']

# %%
fdist9.keys()

# %%
fdist9.values()

# %%
fdist9.plot(50, cumulative=True,title='first 50 frequencies')

# %%
fdist9.tabulate()

# %% [markdown]
# Selecting words with one to three letters

# %%
Doc = set(text2)
some_words = [w for w in Doc if len(w) in range(1,4)]
sorted(some_words)

# %% [markdown]
# ## Collocations and Bigrams

# %% [markdown]
# A collocation is a sequence of words that occur together unusually often. Thus redwine is a collocation, whereas the wine is not

# %%
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; God
# bless; Chief Justice; Old World; Almighty God; Fellow citizens; Chief
# Magistrate; every citizen; one another; fellow Americans; Indian
# tribes; public debt; foreign nations

# %%
#What do you think the output of this code?
max([len(w) for w in text1])
# Out:
# 20

# %%
[w for w in text1 if len(w)==20]
# Out:
# ['uninterpenetratingly']

# %% [markdown]
# [w for w in text if condition]
# Conditions
# <img src="Capture.png">

# %%
#[w for w in text9 if w.startswith('L')]

# %%
#[w for w in text9 if w.isdigit()]

# %%
ALNUM_LIST=[w for w in text9 if w.isalnum()]

# %%
ALNUM_LIST[:3]
# Out:
# ['The', 'Man', 'Who']

# %%
#[w.upper() for w in text9]
