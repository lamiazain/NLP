# %% [markdown]
# #  CH.3

# %%
import re #for reguler expression
import nltk
from nltk import word_tokenize
from nltk.corpus import gutenberg, nps_chat

# %% [markdown]
# ## Extracting word pieces

# %% [markdown]
# <img src="Capture3.png" width="400" height="400">
# <img src="Capture4.png" width="400" height="400">

# %%
word = 'supercalifragilisticexpialidocious'
re.findall(r'[aeiou]', word)
# Out:
# ['u',
#  'e',
#  'a',
#  'i',
#  'a',
#  'i',
#  'i',
#  'i',
#  'e',
#  'i',
#  'a',
#  'i',
#  'o',
#  'i',
#  'o',
#  'u']

# %%
len(re.findall(r'[aeiou]', word))
16
# Out:
# 16

# %%
wsj = sorted(set(nltk.corpus.treebank.words())) # treebankis a corbus
 # nltk.corpus.brown is brown corpus
wsj
# Out:
# ['!',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  "''",
#  "'30s",
#  "'40s",
#  "'50s",
#  "'80s",
#  "'82",
#  "'86",
#  "'S",
#  "'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  '*',
#  '*-1',
#  '*-10',
#  '*-100',
#  '*-101',
#  '*-102',
#  '*-103',
#  '*-104',
#  '*-105',
#  '*-106',
#  '*-107',
#  '*-108',
#  '*-109',
#  '*-11',
#  '*-110',
#  '*-111',
#  '*-112',
#  '*-113',
#  '*-114',
#  '*-115',
#  '*-116',
#  '*-117',
#  '*-118',
#  '*-119',
#  '*-12',
#  '*-120',
#  '*-121',
#  '*-122',
#  '*-123',
#  '*-124',
#  '*-125',
#  '*-126',
#  '*-127',
#  '*-128',
#  '*-129',
#  '*-13',
#  '*-130',
#  '*-131',
#  '*-132',
#  '*-133',
#  '*-134',
#  '*-135',
#  '*-136',
#  '*-137',
#  '*-138',
#  '*-139',
#  '*-14',
#  '*-140',
#  '*-141',
#  '*-142',
#  '*-144',
#  '*-145',
#  '*-146',
#  '*-147',
#  '*-149',
#  '*-15',
#  '*-150',
#  '*-151',
#  '*-152',
#  '*-153',
#  '*-154',
#  '*-155',
#  '*-156',
#  '*-157',
#  '*-158',
#  '*-159',
#  '*-16',
#  '*-160',
# ...

# %% [markdown]
# Find appearences of two consequent vowels

# %%
fd = nltk.FreqDist(vs for word in wsj for vs in re.findall(r'[aeiou]{2,}', word))
#fd
print(fd.most_common(12))
# Out:
# [('io', 549), ('ea', 476), ('ie', 331), ('ou', 329), ('ai', 261), ('ia', 253), ('ee', 217), ('oo', 174), ('ua', 109), ('au', 106), ('ue', 105), ('ui', 95)]

# %% [markdown]
# Finding email addresses from text

# %%
statement = """Dear Dr. Amr, please emailme on lamiahasan4@gmail.com or Mohammed  at 
Mo.Zyad@outlook.com"""
# \S matches any non-whitespace character  
# @ for as in the Email  
# + for Repeats a character one or more times  
lst = re.findall('\S+@\S+', statement)      
  
# Printing of List  
print(lst)
# Out:
# ['lamiahasan4@gmail.com', 'Mo.Zyad@outlook.com']

# %% [markdown]
# ### To do
# Your Turn: In the W3C Date Time Format, dates are represented like this: 2009-12-31. Replace the ? in the following Python code with a regular expression, in order to convert the string '2009-12-31' to a list of integers [2009, 12, 31]:
#
# [int(n) for n in re.findall(?, '2009-12-31')]

# %%
s = "My birthday is on 01-02-1994 and my father's birthday is on 01-07-1994"
Dates= re.findall(r'\d{2}-\d{2}-\d{4}', s)
Dates
# Out:
# ['01-02-1994', '01-07-1994']

# %% [markdown]
# ## Finding Word Stems

# %% [markdown]
# Function to return all words stemmed from given suffixes

# %%
Suffixes=['ing', 'ly', 'ed', 'ious', 'ies', 'ive', 'es', 's', 'ment']

def stem(word):
    for suffix in Suffixes:
        if word.endswith(suffix):
            return word[:-len(suffix)]
    return word
stem("musically")
# Out:
# 'musical'

# %% [markdown]
# Build up a disjunction of all the suffixes

# %%
re.findall(r'^.*(ing|ly|ed|ious|ies|ive|es|s|ment)$', 'processing') #parentheses have a second function, to select substrings to be extracted
# Out:
# ['ing']

# %% [markdown]
# If we want to use the parentheses to specify the scope of the disjunction,
# but not to select the material to be output, we have to add ?:

# %%
re.findall(r'^.*(?:ing|ly|ed|ious|ies|ive|es|s|ment)$', 'processing')
# Out:
# ['processing']

# %% [markdown]
# However, we'd actually like to split the word into stem and suffix

# %%
re.findall(r'^(.*)(ing|ly|ed|ious|ies|ive|es|s|ment)$', 'processes')
# Out:
# [('processe', 's')]

# %%
re.findall(r'^(.*?)(ing|ly|ed|ious|ies|ive|es|s|ment)$', 'processes')
#non greedy * operator
# Out:
# [('process', 'es')]

# %% [markdown]
# This works even when we allow an empty suffix, by making the content of the second parentheses optional:

# %%
re.findall(r'^(.*?)(ing|ly|ed|ious|ies|ive|es|s|ment)?$', 'language')
#non greedy * operator
# Out:
# [('language', '')]

# %% [markdown]
# Generalizing a function to print word and stem

# %%
Stemmed_words=[]
def stem(Sent):
    tokens = word_tokenize(Sent)
    regexp = r'^(.*?)(ing|ly|ed|ious|ies|ive|es|s|ment)?$'
    for word in tokens:
        stem, suffix = re.findall(regexp, word)[0]
        Stemmed_words.append(stem)
    return Stemmed_words
raw = """DENNIS: Listen, strange women lying in ponds distributing swords
is no basis for a system of government.  Supreme executive power derives from
a mandate from the masses, not from some farcical aquatic ceremony."""
stem(raw)
# Out:
# ['DENNIS',
#  ':',
#  'Listen',
#  ',',
#  'strange',
#  'women',
#  'ly',
#  'in',
#  'pond',
#  'distribut',
#  'sword',
#  'i',
#  'no',
#  'basi',
#  'for',
#  'a',
#  'system',
#  'of',
#  'govern',
#  '.',
#  'Supreme',
#  'execut',
#  'power',
#  'deriv',
#  'from',
#  'a',
#  'mandate',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcical',
#  'aquatic',
#  'ceremony',
#  '.']

# %% [markdown]
# ## Searching Tokenized Text

# %% [markdown]
# For example, "\<a> \<man>" finds all instances of a man in the text. The angle brackets are used to mark token boundaries, and any whitespace between the angle brackets is ignored (behaviors that are unique to NLTK's findall() method for texts)

# %% [markdown]
# In the following example, we include <.*>  which will match any single token, and enclose it in parentheses so only the matched word (e.g. monied) and not the matched phrase (e.g. a monied man) is produced

# %%
moby = nltk.Text(gutenberg.words('melville-moby_dick.txt'))
moby.findall(r"<a> (<.*>) <man>")
# Out:
# monied; nervous; dangerous; white; white; white; pious; queer; good;
# mature; white; Cape; great; wise; wise; butterless; white; fiendish;
# pale; furious; better; certain; complete; dismasted; younger; brave;
# brave; brave; brave

# %%
chat = nltk.Text(nps_chat.words())
chat.findall(r"<.*> <.*> <bro>")
# Out:
# you rule bro; telling you bro; u twizted bro

# %%
chat.findall(r"<l.*>{3,}")
# Out:
# lol lol lol; lmao lol lol; lol lol lol; la la la la la; la la la; la
# la la; lovely lol lol love; lol lol lol.; la la la; la la la

# %% [markdown]
# Finding all sentences containing specified words

# %%
from nltk.corpus import brown
hobbies_learned = nltk.Text(brown.words(categories=['hobbies', 'learned']))
#obbies_learned
hobbies_learned.findall(r"<\w*> <and> <other> <\w*s>")
# Out:
# speed and other activities; water and other liquids; tomb and other
# landmarks; Statues and other monuments; pearls and other jewels;
# charts and other items; roads and other features; figures and other
# objects; military and other areas; demands and other factors;
# abstracts and other compilations; iron and other metals

# %% [markdown]
# ## Regular Expressions for Detecting Word Patterns

# %%
wordlist = [w for w in nltk.corpus.words.words('en') if w.islower()]  #finds english lower case letters
wordlist
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aardvark',
#  'aardwolf',
#  'aba',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abaptiston',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abash',
#  'abashed',
#  'abashedly',
#  'abashedness',
#  'abashless',
#  'abashlessly',
#  'abashment',
#  'abasia',
#  'abasic',
#  'abask',
#  'abastardize',
#  'abatable',
#  'abate',
#  'abatement',
#  'abater',
#  'abatis',
#  'abatised',
#  'abaton',
# ...

# %%
path = nltk.data.find('corpora/words')
print(path)
# Out:
# C:\Users\Lamia\AppData\Roaming\nltk_data\corpora\words

# %%
[w for w in wordlist if re.search('ed$', w)]  # $ --> ends with 
# finds letters ending with “ed”
# Out:
# ['abaissed',
#  'abandoned',
#  'abased',
#  'abashed',
#  'abatised',
#  'abed',
#  'aborted',
#  'abridged',
#  'abscessed',
#  'absconded',
#  'absorbed',
#  'abstracted',
#  'abstricted',
#  'accelerated',
#  'accepted',
#  'accidented',
#  'accoladed',
#  'accolated',
#  'accomplished',
#  'accosted',
#  'accredited',
#  'accursed',
#  'accused',
#  'accustomed',
#  'acetated',
#  'acheweed',
#  'aciculated',
#  'aciliated',
#  'acknowledged',
#  'acorned',
#  'acquainted',
#  'acquired',
#  'acquisited',
#  'acred',
#  'aculeated',
#  'addebted',
#  'added',
#  'addicted',
#  'addlebrained',
#  'addleheaded',
#  'addlepated',
#  'addorsed',
#  'adempted',
#  'adfected',
#  'adjoined',
#  'admired',
#  'admitted',
#  'adnexed',
#  'adopted',
#  'adossed',
#  'adreamed',
#  'adscripted',
#  'aduncated',
#  'advanced',
#  'advised',
#  'aeried',
#  'aethered',
#  'afeared',
#  'affected',
#  'affectioned',
#  'affined',
#  'afflicted',
#  'affricated',
#  'affrighted',
# ...

# %%
[w for w in wordlist if re.search('^..j..t..$', w)] # ^ --> starts with 
#search for any word that ends with (two letthers, then letter c then two letters
# then lretter t then two letters ending the word)
# Out:
# ['abjectly',
#  'adjuster',
#  'dejected',
#  'dejectly',
#  'injector',
#  'majestic',
#  'objectee',
#  'objector',
#  'rejecter',
#  'rejector',
#  'unjilted',
#  'unjolted',
#  'unjustly']

# %%
chat_words = sorted(set(w for w in nltk.corpus.nps_chat.words()))
[w for w in chat_words if re.search('^m+i+n+e+$', w)]
# Out:
# ['miiiiiiiiiiiiinnnnnnnnnnneeeeeeeeee',
#  'miiiiiinnnnnnnnnneeeeeeee',
#  'mine',
#  'mmmmmmmmiiiiiiiiinnnnnnnnneeeeeeee']

# %%
[w for w in chat_words if re.search('^[ha]+$', w)] #starts with h or and ends with a or h as well
# Out:
# ['a',
#  'aaaaaaaaaaaaaaaaa',
#  'aaahhhh',
#  'ah',
#  'ahah',
#  'ahahah',
#  'ahh',
#  'ahhahahaha',
#  'ahhh',
#  'ahhhh',
#  'ahhhhhh',
#  'ahhhhhhhhhhhhhh',
#  'h',
#  'ha',
#  'haaa',
#  'hah',
#  'haha',
#  'hahaaa',
#  'hahah',
#  'hahaha',
#  'hahahaa',
#  'hahahah',
#  'hahahaha',
#  'hahahahaaa',
#  'hahahahahaha',
#  'hahahahahahaha',
#  'hahahahahahahahahahahahahahahaha',
#  'hahahhahah',
#  'hahhahahaha']

# %% [markdown]
# <img src="Capture2.png" width="800" height="400">

# %% [markdown]
# ##  Regular Expressions for Tokenizing Text

# %% [markdown]
# Please see the lecture slides to know more about  Regular Expressions for Tokenizing Text

# %% [markdown]
#  ## Normalizing Text

# %%
 raw = """DENNIS: Listen, strange women lying in ponds distributing swords
...is no basis for a system of government.  Supreme executive power derives from
... a mandate from the masses, not from some farcical aquatic ceremony."""
tokens = word_tokenize(raw)
tokens
# Out:
# ['DENNIS',
#  ':',
#  'Listen',
#  ',',
#  'strange',
#  'women',
#  'lying',
#  'in',
#  'ponds',
#  'distributing',
#  'swords',
#  '...',
#  'is',
#  'no',
#  'basis',
#  'for',
#  'a',
#  'system',
#  'of',
#  'government',
#  '.',
#  'Supreme',
#  'executive',
#  'power',
#  'derives',
#  'from',
#  '...',
#  'a',
#  'mandate',
#  'from',
#  'the',
#  'masses',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcical',
#  'aquatic',
#  'ceremony',
#  '.']

# %%
porter = nltk.PorterStemmer()
lancaster = nltk.LancasterStemmer()
print("POrter stemmer result ",[porter.stem(t) for t in tokens])
print("Lancaster stemmer result ", [lancaster.stem(t) for t in tokens])
# Out:
# POrter stemmer result  ['denni', ':', 'listen', ',', 'strang', 'women', 'lie', 'in', 'pond', 'distribut', 'sword', '...', 'is', 'no', 'basi', 'for', 'a', 'system', 'of', 'govern', '.', 'suprem', 'execut', 'power', 'deriv', 'from', '...', 'a', 'mandat', 'from', 'the', 'mass', ',', 'not', 'from', 'some', 'farcic', 'aquat', 'ceremoni', '.']
# Lancaster stemmer result  ['den', ':', 'list', ',', 'strange', 'wom', 'lying', 'in', 'pond', 'distribut', 'sword', '...', 'is', 'no', 'bas', 'for', 'a', 'system', 'of', 'govern', '.', 'suprem', 'execut', 'pow', 'der', 'from', '...', 'a', 'mand', 'from', 'the', 'mass', ',', 'not', 'from', 'som', 'farc', 'aqu', 'ceremony', '.']

# %% [markdown]
# ## lematization

# %%
wn_lemmatizer = nltk.WordNetLemmatizer()
[wn_lemmatizer.lemmatize(t) for t in tokens]
# Out:
# ['DENNIS',
#  ':',
#  'Listen',
#  ',',
#  'strange',
#  'woman',
#  'lying',
#  'in',
#  'pond',
#  'distributing',
#  'sword',
#  '...',
#  'is',
#  'no',
#  'basis',
#  'for',
#  'a',
#  'system',
#  'of',
#  'government',
#  '.',
#  'Supreme',
#  'executive',
#  'power',
#  'derives',
#  'from',
#  '...',
#  'a',
#  'mandate',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcical',
#  'aquatic',
#  'ceremony',
#  '.']

# %% [markdown]
# # Excercise 1 Splitting documents and sentences

# %% [markdown]
# ## Splitting a document into sentenses (Segmentation) using re
# ## Regular Expressions for Tokenizing Text/

# %%
def sent_tokenize(text):
    
    #Sent=Text.split(",") For one delimeter based split
    Sent=re.split(r'[,.?!]', text)  #for multible delimeters based split
    for i in range(len(Sent)):
        Sent[i]=Sent[i].strip() #remove leading and trailing space 
    if '' in Sent:
        Sent.remove('')
    return Sent


#Test your func.
#Text="As I'm waiting, a man came out of a side room, and at a glance I was sure he must be Long John. His left leg was cut off close by the hip, and under the left shoulder he carried a crutch, which he managed with wonderful dexterity, hopping about upon it like a bird. He was very tall and strong, with a face as big as a ham—plain and pale, but intelligent and smiling. Indeed, he seemed in the most cheerful spirits, whistling as he moved about among the tables, with a merry word or a slap on the shoulder for the more favoured of his guests."
#sent_tokenize(Text)

# %% [markdown]
# ## Splitting a document into sentenses (Sentense Segmentation) using NLTK

# %%
import nltk, pprint

text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war? Is AI a bad thing?"
sents = nltk.sent_tokenize(text)
pprint.pprint(sents)
#print(sents)
# Out:
# ['The first time you see The Second Renaissance it may look boring.',
#  'Look at it at least twice and definitely watch part 2.',
#  'It will change your view of the matrix.',
#  'Are the human people the ones who started the war?',
#  'Is AI a bad thing?']

# %% [markdown]
# ## Splitting sentenses into words

# %%
def word_tokenize(sent):
    """Split a sentence into words."""
    
    # TODO: Split sent by word delimiters (remove delimiters)
    
    # TODO: Remove leading and trailing spaces from each word
    
    pass  # TODO: Return a list of words (remove blank strings)

# %%
#solution
def word_tokenize(sent):
    """Split a sentence into words."""
    
    # TODO: Split sent by word delimiters (remove delimiters)
    #words=re.split(r'[^\w]',sent) #split by words
    words=sent.split()            #splits at spaces
    # TODO: Remove leading and trailing spaces from each word
    for i in range(len(words)):
        words[i]=words[i].strip()
    return words  # TODO: Return a list of words (remove blank strings)

#Test your function
#Sent="with a face as big as a ham—plain and pale"
#word_tokenize(Sent)

# %%
def test_run():
    """Called on Test Run."""

    text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war? Is AI a bad thing?"
    print("--- Sample text ---", text, sep="\n")
    
    sentences = sent_tokenize(text)
    print("\n--- Sentences ---")
    print(sentences)
    
    print("\n--- Words ---")
    for sent in sentences:
        print(sent)
        print(word_tokenize(sent))
        print()  # blank line for readability
test_run()
# Out:
# --- Sample text ---
# The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war? Is AI a bad thing?
#
# --- Sentences ---
# ['The first time you see The Second Renaissance it may look boring', 'Look at it at least twice and definitely watch part 2', 'It will change your view of the matrix', 'Are the human people the ones who started the war', 'Is AI a bad thing']
#
# --- Words ---
# The first time you see The Second Renaissance it may look boring
# ['The', 'first', 'time', 'you', 'see', 'The', 'Second', 'Renaissance', 'it', 'may', 'look', 'boring']
#
# Look at it at least twice and definitely watch part 2
# ['Look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2']
#
# It will change your view of the matrix
# ['It', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix']
#
# ...
